# %% [markdown]
# <a href="https://colab.research.google.com/github/taegyeonglee96/class2022spring/blob/main/20220328.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gradio
import gradio as gr
import requests
import pandas as pd

# %%
URL = ('http://apis.data.go.kr/B552584/OzYlwsndOccrrncInforInqireSvc/'
      'getOzAdvsryOccrrncInfo?'
      'year=2020'
      '&pageNo=1'
      '&numOfRows=100'
      '&returnType=json'
      '&serviceKey=jW4ZPnRXy6XNJF4WzOzsepRR4qn0Hsa8uAlA0vO71tNdW%2BHaMLHOEcWufB960M6tjN3vn9vpr%2BqIjp48CZSSRg%3D%3D')
response = requests.get(URL)

# %%
response
# Out:
# <Response [200]>

# %%
r = response.json()
r
# Out:
# {'response': {'body': {'items': [{'clearTime': '19',
#      'clearVal': '0.103',
#      'dataDate': '2020-09-28',
#      'districtName': '충남',
#      'issueLvl': None,
#      'issueTime': '18',
#      'issueVal': '0.137',
#      'maxVal': '0.137',
#      'moveName': '서산시',
#      'sn': '295'},
#     {'clearTime': '20',
#      'clearVal': '0.087',
#      'dataDate': '2020-09-28',
#      'districtName': '충남',
#      'issueLvl': None,
#      'issueTime': '19',
#      'issueVal': '0.126',
#      'maxVal': '0.126',
#      'moveName': '당진시',
#      'sn': '296'},
#     {'clearTime': '18',
#      'clearVal': '0.078',
#      'dataDate': '2020-09-20',
#      'districtName': '경북',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.153',
#      'maxVal': '0.153',
#      'moveName': '봉화군',
#      'sn': '294'},
#     {'clearTime': '16',
#      'clearVal': '0.100',
#      'dataDate': '2020-09-10',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.122',
#      'maxVal': '0.122',
#      'moveName': '광양시',
#      'sn': '292'},
#     {'clearTime': '14',
#      'clearVal': '0.093',
#      'dataDate': '2020-09-10',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.122',
#      'maxVal': '0.122',
#      'moveName': '여수시',
#      'sn': '291'},
#     {'clearTime': '19',
#      'clearVal': '0.097',
#      'dataDate': '2020-09-08',
#      'districtName': '제주',
#      'issueLvl': None,
#      'issueTime': '11',
#      'issueVal': '0.125',
#      'maxVal': '0.125',
#      'moveName': '제주권역',
#      'sn': '290'},
#     {'clearTime': '19',
#      'clearVal': '0.089',
#      'dataDate': '2020-09-04',
#      'districtName': '경북',
#      'issueLvl': None,
#      'issueTime': '18',
#      'issueVal': '0.12',
#      'maxVal': '0.12',
#      'moveName': '포항시',
#      'sn': '289'},
#     {'clearTime': '15',
#      'clearVal': '0.092',
#      'dataDate': '2020-08-30',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.133',
#      'maxVal': '0.133',
#      'moveName': '여수시',
#      'sn': '286'},
#     {'clearTime': '18',
#      'clearVal': '0.102',
#      'dataDate': '2020-08-30',
#      'districtName': '충남',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.120',
#      'maxVal': '0.120',
#      'moveName': '당진시',
#      'sn': '288'},
#     {'clearTime': '16',
#      'clearVal': '0.115',
#      'dataDate': '2020-08-30',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.138',
#      'maxVal': '0.138',
#      'moveName': '남해군',
#      'sn': '287'},
#     {'clearTime': '17',
#      'clearVal': '0.088',
#      'dataDate': '2020-08-23',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.131',
#      'maxVal': '0.131',
#      'moveName': '하동군',
#      'sn': '284'},
#     {'clearTime': '15',
#      'clearVal': '0.118',
#      'dataDate': '2020-08-23',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.150',
#      'maxVal': '0.150',
#      'moveName': '광양시',
#      'sn': '283'},
#     {'clearTime': '16',
#      'clearVal': '0.109',
#      'dataDate': '2020-08-23',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.120',
#      'maxVal': '0.144',
#      'moveName': '여수시',
#      'sn': '282'},
#     {'clearTime': '18',
#      'clearVal': '0.114',
#      'dataDate': '2020-08-23',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.131',
#      'maxVal': '0.131',
#      'moveName': '순천시',
#      'sn': '285'},
#     {'clearTime': '18',
#      'clearVal': '0.102',
#      'dataDate': '2020-08-21',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.123',
#      'maxVal': '0.123',
#      'moveName': '김해시',
#      'sn': '280'},
#     {'clearTime': '17',
#      'clearVal': '0.108',
#      'dataDate': '2020-08-21',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.129',
#      'maxVal': '0.146',
#      'moveName': '창원시 의창구·성산구',
#      'sn': '276'},
#     {'clearTime': '17',
#      'clearVal': '0.109',
#      'dataDate': '2020-08-21',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.132',
#      'maxVal': '0.143',
#      'moveName': '순천시',
#      'sn': '278'},
#     {'clearTime': '19',
#      'clearVal': '0.068',
#      'dataDate': '2020-08-21',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.126',
#      'maxVal': '0.146',
#      'moveName': '광양시',
#      'sn': '279'},
#     {'clearTime': '16',
#      'clearVal': '0.119',
#      'dataDate': '2020-08-21',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.128',
#      'maxVal': '0.133',
#      'moveName': '김해시',
#      'sn': '277'},
#     {'clearTime': '16',
#      'clearVal': '0.111',
#      'dataDate': '2020-08-20',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.128',
#      'maxVal': '0.162',
#      'moveName': '여수시',
#      'sn': '265'},
#     {'clearTime': '14',
#      'clearVal': '0.095',
#      'dataDate': '2020-08-20',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.125',
#      'maxVal': '0.125',
#      'moveName': '동구 전역',
#      'sn': '262'},
#     {'clearTime': '16',
#      'clearVal': '0.118',
#      'dataDate': '2020-08-20',
#      'districtName': '부산',
#      'issueLvl': None,
#      'issueTime': '11',
#      'issueVal': '0.141',
#      'maxVal': '0.141',
#      'moveName': '남부',
#      'sn': '260'},
#     {'clearTime': '18',
#      'clearVal': '0.113',
#      'dataDate': '2020-08-20',
#      'districtName': '부산',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.137',
#      'maxVal': '0.137',
#      'moveName': '남부',
#      'sn': '274'},
#     {'clearTime': '17',
#      'clearVal': '0.099',
#      'dataDate': '2020-08-20',
#      'districtName': '부산',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.172',
#      'maxVal': '0.172',
#      'moveName': '서부',
#      'sn': '268'},
#     {'clearTime': '19',
#      'clearVal': '0.102',
#      'dataDate': '2020-08-20',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.154',
#      'maxVal': '0.166',
#      'moveName': '김해시',
#      'sn': '267'},
#     {'clearTime': '16',
#      'clearVal': '0.116',
#      'dataDate': '2020-08-20',
#      'districtName': '부산',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.140',
#      'maxVal': '0.160',
#      'moveName': '중부',
#      'sn': '261'},
#     {'clearTime': '19',
#      'clearVal': '0.117',
#      'dataDate': '2020-08-20',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.138',
#      'maxVal': '0.138',
#      'moveName': '하동군',
#      'sn': '273'},
#     {'clearTime': '19',
#      'clearVal': '0.077',
#      'dataDate': '2020-08-20',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.125',
#      'maxVal': '0.133',
#      'moveName': '중부권',
#      'sn': '269'},
#     {'clearTime': '19',
#      'clearVal': '0.114',
#      'dataDate': '2020-08-20',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.141',
#      'maxVal': '0.159',
#      'moveName': '창원시 의창구·성산구',
#      'sn': '270'},
#     {'clearTime': '18',
#      'clearVal': '0.114',
#      'dataDate': '2020-08-20',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.123',
#      'maxVal': '0.125',
#      'moveName': '창원시 마산회원구·마산합포구',
#      'sn': '266'},
#     {'clearTime': '19',
#      'clearVal': '0.099',
#      'dataDate': '2020-08-20',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '18',
#      'issueVal': '0.149',
#      'maxVal': '0.149',
#      'moveName': '밀양시',
#      'sn': '275'},
#     {'clearTime': '16',
#      'clearVal': '0.104',
#      'dataDate': '2020-08-20',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.142',
#      'maxVal': '0.149',
#      'moveName': '양산시',
#      'sn': '263'},
#     {'clearTime': '17',
#      'clearVal': '0.117',
#      'dataDate': '2020-08-20',
#      'districtName': '부산',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.128',
#      'maxVal': '0.128',
#      'moveName': '동부',
#      'sn': '271'},
#     {'clearTime': '15',
#      'clearVal': '0.090',
#      'dataDate': '2020-08-20',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.136',
#      'maxVal': '0.136',
#      'moveName': '울주군',
#      'sn': '264'},
#     {'clearTime': '15',
#      'clearVal': '0.097',
#      'dataDate': '2020-08-20',
#      'districtName': '부산',
#      'issueLvl': None,
#      'issueTime': '11',
#      'issueVal': '0.141',
#      'maxVal': '0.178',
#      'moveName': '동부',
#      'sn': '259'},
#     {'clearTime': '19',
#      'clearVal': '0.084',
#      'dataDate': '2020-08-20',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.125',
#      'maxVal': '0.125',
#      'moveName': '남부권',
#      'sn': '272'},
#     {'clearTime': '17',
#      'clearVal': '0.090',
#      'dataDate': '2020-08-19',
#      'districtName': '부산',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.123',
#      'maxVal': '0.123',
#      'moveName': '동부',
#      'sn': '252'},
#     {'clearTime': '15',
#      'clearVal': '0.115',
#      'dataDate': '2020-08-19',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '12',
#      'issueVal': '0.127',
#      'maxVal': '0.144',
#      'moveName': '동구 전역',
#      'sn': '247'},
#     {'clearTime': '17',
#      'clearVal': '0.116',
#      'dataDate': '2020-08-19',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.128',
#      'maxVal': '0.128',
#      'moveName': '하동군',
#      'sn': '254'},
#     {'clearTime': '15',
#      'clearVal': '0.086',
#      'dataDate': '2020-08-19',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.136',
#      'maxVal': '0.136',
#      'moveName': '중구 전역',
#      'sn': '249'},
#     {'clearTime': '15',
#      'clearVal': '0.114',
#      'dataDate': '2020-08-19',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.126',
#      'maxVal': '0.126',
#      'moveName': '여수시',
#      'sn': '250'},
#     {'clearTime': '20',
#      'clearVal': '0.077',
#      'dataDate': '2020-08-19',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '18',
#      'issueVal': '0.125',
#      'maxVal': '0.125',
#      'moveName': '사천시',
#      'sn': '258'},
#     {'clearTime': '19',
#      'clearVal': '0.099',
#      'dataDate': '2020-08-19',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.138',
#      'maxVal': '0.138',
#      'moveName': '울주군',
#      'sn': '256'},
#     {'clearTime': '18',
#      'clearVal': '0.098',
#      'dataDate': '2020-08-19',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.123',
#      'maxVal': '0.126',
#      'moveName': '양산시',
#      'sn': '253'},
#     {'clearTime': '18',
#      'clearVal': '0.092',
#      'dataDate': '2020-08-19',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.121',
#      'maxVal': '0.121',
#      'moveName': '동구 전역',
#      'sn': '257'},
#     {'clearTime': '18',
#      'clearVal': '0.106',
#      'dataDate': '2020-08-19',
#      'districtName': '부산',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.124',
#      'maxVal': '0.124',
#      'moveName': '중부',
#      'sn': '255'},
#     {'clearTime': '17',
#      'clearVal': '0.071',
#      'dataDate': '2020-08-19',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.124',
#      'maxVal': '0.124',
#      'moveName': '남해군',
#      'sn': '251'},
#     {'clearTime': '15',
#      'clearVal': '0.081',
#      'dataDate': '2020-08-19',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.136',
#      'maxVal': '0.136',
#      'moveName': '남구 전역',
#      'sn': '248'},
#     {'clearTime': '16',
#      'clearVal': '0.105',
#      'dataDate': '2020-08-18',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.142',
#      'maxVal': '0.188',
#      'moveName': '동구 전역',
#      'sn': '240'},
#     {'clearTime': '17',
#      'clearVal': '0.110',
#      'dataDate': '2020-08-18',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.120',
#      'maxVal': '0.122',
#      'moveName': '남구 전역',
#      'sn': '244'},
#     {'clearTime': '18',
#      'clearVal': '0.111',
#      'dataDate': '2020-08-18',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.139',
#      'maxVal': '0.139',
#      'moveName': '하동군',
#      'sn': '245'},
#     {'clearTime': '19',
#      'clearVal': '0.103',
#      'dataDate': '2020-08-18',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '18',
#      'issueVal': '0.125',
#      'maxVal': '0.125',
#      'moveName': '동부권',
#      'sn': '246'},
#     {'clearTime': '16',
#      'clearVal': '0.102',
#      'dataDate': '2020-08-18',
#      'districtName': '부산',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.122',
#      'maxVal': '0.122',
#      'moveName': '남부',
#      'sn': '243'},
#     {'clearTime': '16',
#      'clearVal': '0.099',
#      'dataDate': '2020-08-18',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.123',
#      'maxVal': '0.133',
#      'moveName': '여수시',
#      'sn': '241'},
#     {'clearTime': '18',
#      'clearVal': '0.099',
#      'dataDate': '2020-08-18',
#      'districtName': '서울',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.128',
#      'maxVal': '0.135',
#      'moveName': '동북권',
#      'sn': '242'},
#     {'clearTime': '18',
#      'clearVal': '0.110',
#      'dataDate': '2020-08-17',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.124',
#      'maxVal': '0.124',
#      'moveName': '남구 전역',
#      'sn': '239'},
#     {'clearTime': '17',
#      'clearVal': '0.105',
#      'dataDate': '2020-07-21',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.121',
#      'maxVal': '0.121',
#      'moveName': '중부권',
#      'sn': '238'},
#     {'clearTime': '19',
#      'clearVal': '0.1',
#      'dataDate': '2020-07-17',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '18',
#      'issueVal': '0.12',
#      'maxVal': '0.120',
#      'moveName': '남부권',
#      'sn': '236'},
#     {'clearTime': '16',
#      'clearVal': '0.092',
#      'dataDate': '2020-07-16',
#      'districtName': '충남',
#      'issueLvl': None,
#      'issueTime': '12',
#      'issueVal': '0.144',
#      'maxVal': '0.144',
#      'moveName': '서산시',
#      'sn': '231'},
#     {'clearTime': '18',
#      'clearVal': '0.109',
#      'dataDate': '2020-07-16',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.123',
#      'maxVal': '0.126',
#      'moveName': '중부권',
#      'sn': '233'},
#     {'clearTime': '20',
#      'clearVal': '0.102',
#      'dataDate': '2020-07-16',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.128',
#      'maxVal': '0.136',
#      'moveName': '남부권',
#      'sn': '232'},
#     {'clearTime': '19',
#      'clearVal': '0.116',
#      'dataDate': '2020-07-16',
#      'districtName': '충남',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.120',
#      'maxVal': '0.135',
#      'moveName': '천안시',
#      'sn': '234'},
#     {'clearTime': '17',
#      'clearVal': '0.118',
#      'dataDate': '2020-07-16',
#      'districtName': '충남',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.126',
#      'maxVal': '0.126',
#      'moveName': '아산시',
#      'sn': '235'},
#     {'clearTime': '17',
#      'clearVal': '0.118',
#      'dataDate': '2020-07-09',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.123',
#      'maxVal': '0.129',
#      'moveName': '북부권',
#      'sn': '228'},
#     {'clearTime': '17',
#      'clearVal': '0.107',
#      'dataDate': '2020-07-09',
#      'districtName': '충남',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.120',
#      'maxVal': '0.157',
#      'moveName': '서산시',
#      'sn': '227'},
#     {'clearTime': '18',
#      'clearVal': '0.114',
#      'dataDate': '2020-07-09',
#      'districtName': '인천',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.134',
#      'maxVal': '0.140',
#      'moveName': '서부권역',
#      'sn': '226'},
#     {'clearTime': '18',
#      'clearVal': '0.111',
#      'dataDate': '2020-07-09',
#      'districtName': '인천',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.136',
#      'maxVal': '0.146',
#      'moveName': '동남부권역',
#      'sn': '229'},
#     {'clearTime': '20',
#      'clearVal': '0.107',
#      'dataDate': '2020-07-09',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.145',
#      'maxVal': '0.154',
#      'moveName': '중부권',
#      'sn': '230'},
#     {'clearTime': '16',
#      'clearVal': '0.112',
#      'dataDate': '2020-07-08',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.125',
#      'maxVal': '0.126',
#      'moveName': '순천시',
#      'sn': '222'},
#     {'clearTime': '21',
#      'clearVal': '0.084',
#      'dataDate': '2020-07-08',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '18',
#      'issueVal': '0.124',
#      'maxVal': '0.126',
#      'moveName': '남부권',
#      'sn': '224'},
#     {'clearTime': '20',
#      'clearVal': '0.116',
#      'dataDate': '2020-07-08',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '18',
#      'issueVal': '0.125',
#      'maxVal': '0.125',
#      'moveName': '동부권',
#      'sn': '225'},
#     {'clearTime': '16',
#      'clearVal': '0.101',
#      'dataDate': '2020-07-08',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.121',
#      'maxVal': '0.121',
#      'moveName': '광양시',
#      'sn': '223'},
#     {'clearTime': '17',
#      'clearVal': '0.110',
#      'dataDate': '2020-07-02',
#      'districtName': '인천',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.125',
#      'maxVal': '0.125',
#      'moveName': '서부권역',
#      'sn': '216'},
#     {'clearTime': '20',
#      'clearVal': '0.11',
#      'dataDate': '2020-07-02',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.125',
#      'maxVal': '0.137',
#      'moveName': '북부권',
#      'sn': '217'},
#     {'clearTime': '20',
#      'clearVal': '0.099',
#      'dataDate': '2020-07-02',
#      'districtName': '서울',
#      'issueLvl': None,
#      'issueTime': '19',
#      'issueVal': '0.124',
#      'maxVal': '0.124',
#      'moveName': '도심권',
#      'sn': '221'},
#     {'clearTime': '18',
#      'clearVal': '0.112',
#      'dataDate': '2020-07-02',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.12',
#      'maxVal': '0.120',
#      'moveName': '중부권',
#      'sn': '219'},
#     {'clearTime': '20',
#      'clearVal': '0.099',
#      'dataDate': '2020-07-02',
#      'districtName': '서울',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.122',
#      'maxVal': '0.139',
#      'moveName': '서북권',
#      'sn': '220'},
#     {'clearTime': '17',
#      'clearVal': '0.119',
#      'dataDate': '2020-07-02',
#      'districtName': '인천',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.140',
#      'maxVal': '0.140',
#      'moveName': '동남부권역',
#      'sn': '218'},
#     {'clearTime': '17',
#      'clearVal': '0.111',
#      'dataDate': '2020-06-28',
#      'districtName': '부산',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.122',
#      'maxVal': '0.122',
#      'moveName': '중부',
#      'sn': '215'},
#     {'clearTime': '17',
#      'clearVal': '0.112',
#      'dataDate': '2020-06-28',
#      'districtName': '부산',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.121',
#      'maxVal': '0.121',
#      'moveName': '남부',
#      'sn': '214'},
#     {'clearTime': '16',
#      'clearVal': '0.093',
#      'dataDate': '2020-06-27',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.122',
#      'maxVal': '0.122',
#      'moveName': '여수시',
#      'sn': '210'},
#     {'clearTime': '17',
#      'clearVal': '0.109',
#      'dataDate': '2020-06-27',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '16',
#      'issueVal': '0.121',
#      'maxVal': '0.121',
#      'moveName': '중부권',
#      'sn': '212'},
#     {'clearTime': '18',
#      'clearVal': '0.115',
#      'dataDate': '2020-06-27',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.120',
#      'maxVal': '0.120',
#      'moveName': '나주시',
#      'sn': '213'},
#     {'clearTime': '14',
#      'clearVal': '0.116',
#      'dataDate': '2020-06-27',
#      'districtName': '경남',
#      'issueLvl': None,
#      'issueTime': '12',
#      'issueVal': '0.138',
#      'maxVal': '0.14',
#      'moveName': '양산시',
#      'sn': '206'},
#     {'clearTime': '20',
#      'clearVal': '0.107',
#      'dataDate': '2020-06-27',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.136',
#      'maxVal': '0.141',
#      'moveName': '순천시',
#      'sn': '209'},
#     {'clearTime': '17',
#      'clearVal': '0.116',
#      'dataDate': '2020-06-27',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.142',
#      'maxVal': '0.142',
#      'moveName': '남구 전역',
#      'sn': '211'},
#     {'clearTime': '16',
#      'clearVal': '0.108',
#      'dataDate': '2020-06-27',
#      'districtName': '울산',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.128',
#      'maxVal': '0.144',
#      'moveName': '울주군',
#      'sn': '207'},
#     {'clearTime': '15',
#      'clearVal': '0.089',
#      'dataDate': '2020-06-27',
#      'districtName': '충남',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.123',
#      'maxVal': '0.123',
#      'moveName': '서산시',
#      'sn': '208'},
#     {'clearTime': '18',
#      'clearVal': '0.117',
#      'dataDate': '2020-06-23',
#      'districtName': '경북',
#      'issueLvl': None,
#      'issueTime': '17',
#      'issueVal': '0.127',
#      'maxVal': '0.127',
#      'moveName': '의성군',
#      'sn': '205'},
#     {'clearTime': '20',
#      'clearVal': '0.109',
#      'dataDate': '2020-06-23',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.124',
#      'maxVal': '0.136',
#      'moveName': '동부권',
#      'sn': '197'},
#     {'clearTime': '16',
#      'clearVal': '0.106',
#      'dataDate': '2020-06-23',
#      'districtName': '경북',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.126',
#      'maxVal': '0.126',
#      'moveName': '영천시',
#      'sn': '202'},
#     {'clearTime': '18',
#      'clearVal': '0.110',
#      'dataDate': '2020-06-23',
#      'districtName': '충남',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.130',
#      'maxVal': '0.130',
#      'moveName': '천안시',
#      'sn': '200'},
#     {'clearTime': '20',
#      'clearVal': '0.115',
#      'dataDate': '2020-06-23',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.123',
#      'maxVal': '0.134',
#      'moveName': '남부권',
#      'sn': '196'},
#     {'clearTime': '17',
#      'clearVal': '0.118',
#      'dataDate': '2020-06-23',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '13',
#      'issueVal': '0.13',
#      'maxVal': '0.144',
#      'moveName': '중부권',
#      'sn': '195'},
#     {'clearTime': '14',
#      'clearVal': '0.110',
#      'dataDate': '2020-06-23',
#      'districtName': '전남',
#      'issueLvl': None,
#      'issueTime': '11',
#      'issueVal': '0.142',
#      'maxVal': '0.155',
#      'moveName': '순천시',
#      'sn': '194'},
#     {'clearTime': '15',
#      'clearVal': '0.109',
#      'dataDate': '2020-06-23',
#      'districtName': '경북',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.121',
#      'maxVal': '0.121',
#      'moveName': '구미시',
#      'sn': '201'},
#     {'clearTime': '17',
#      'clearVal': '0.115',
#      'dataDate': '2020-06-23',
#      'districtName': '대구',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.136',
#      'maxVal': '0.136',
#      'moveName': '대구권역',
#      'sn': '203'},
#     {'clearTime': '16',
#      'clearVal': '0.115',
#      'dataDate': '2020-06-23',
#      'districtName': '서울',
#      'issueLvl': None,
#      'issueTime': '15',
#      'issueVal': '0.123',
#      'maxVal': '0.123',
#      'moveName': '동남권',
#      'sn': '204'},
#     {'clearTime': '15',
#      'clearVal': '0.11',
#      'dataDate': '2020-06-23',
#      'districtName': '경기',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.12',
#      'maxVal': '0.120',
#      'moveName': '북부권',
#      'sn': '198'},
#     {'clearTime': '15',
#      'clearVal': '0.113',
#      'dataDate': '2020-06-23',
#      'districtName': '세종',
#      'issueLvl': None,
#      'issueTime': '14',
#      'issueVal': '0.121',
#      'maxVal': '0.121',
#      'moveName': '세종권역',
#      'sn': '199'}],
#    'numOfRows': 100,
#    'pageNo': 1,
#    'totalCount': 293},
#   'header': {'resultCode': '00', 'resultMsg': 'NORMAL_CODE'}}}

# %%
items = r['response']['body']['items']

# %%
  dataDate = [item['dataDate'] for item in items]  
  districtName = [item['districtName'] for item in items]
  moveName = [item['moveName'] for item in items]
  issueTime = [item['issueTime'] for item in items]
  maxVal= [item['maxVal'] for item in items]
  issueLvl = [item['issueLvl'] for item in items]
  issueVal = [item['issueVal'] for item in items]
  clearVal = [item['clearVal'] for item in items]

  dataDate = pd. Series(dataDate)
  districtName = pd.Series(districtName)
  moveName = pd.Series(moveName)
  issueTime = pd.Series(issueTime)
  maxVal = pd.Series(maxVal)
  issueLvl = pd.Series(issueLvl)
  issueVal = pd.Series(issueVal)
  clearVal = pd.Series(clearVal)

  df = pd.DataFrame({'dataDate': dataDate,'districtName' : districtName, 'moveName' : moveName, 'issueTime': issueTime,'maxVal': maxVal,'issueLvl': issueLvl, 'issueVal': issueVal,'clearVal': clearVal})

# %%
df

# %%
def test(year):
  URL = ('http://apis.data.go.kr/B552584/OzYlwsndOccrrncInforInqireSvc/'
      'getOzAdvsryOccrrncInfo?'
      'year='+year+
      '&pageNo=1'
      '&numOfRows=100'
      '&returnType=json'
      '&serviceKey=jW4ZPnRXy6XNJF4WzOzsepRR4qn0Hsa8uAlA0vO71tNdW%2BHaMLHOEcWufB960M6tjN3vn9vpr%2BqIjp48CZSSRg%3D%3D')

  response = requests.get(URL)
  r = response.json()
  items = r['response']['body']['items']

  dataDate = [item['dataDate'] for item in items]  
  districtName = [item['districtName'] for item in items]
  moveName = [item['moveName'] for item in items]
  issueTime = [item['issueTime'] for item in items]
  maxVal= [item['maxVal'] for item in items]
  issueLvl = [item['issueLvl'] for item in items]
  issueVal = [item['issueVal'] for item in items]
  clearVal = [item['clearVal'] for item in items]

  dataDate = pd. Series(dataDate)
  districtName = pd.Series(districtName)
  moveName = pd.Series(moveName)
  issueTime = pd.Series(issueTime)
  maxVal = pd.Series(maxVal)
  issueLvl = pd.Series(issueLvl)
  issueVal = pd.Series(issueVal)
  clearVal = pd.Series(clearVal)

  df = pd.DataFrame({'dataDate': dataDate,'districtName' : districtName, 'moveName' : moveName, 'issueTime': issueTime,'maxVal': maxVal,'issueLvl': issueLvl, 'issueVal': issueVal,'clearVal': clearVal})
  return df

# %%
iface = gr.Interface(test, gr.inputs.Dropdown(['2019','2020','2021']), outputs=['dataframe'])
iface.launch(debug=True)
# Out:
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# Running on public URL: https://42450.gradio.app
#
# This share link expires in 72 hours. For free permanent hosting, check out Spaces (https://huggingface.co/spaces)
#         <iframe
#             width="900"
#             height="500"
#             src="https://42450.gradio.app"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
